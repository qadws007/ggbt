# %%
import pandas as pd
import os
import numpy as np

path_root = os.getcwd()

# %%
df=pd.read_csv(os.getcwd()+"/datas/tdx/SH#600519.csv",
               skiprows=[0,1],skipfooter=1,encoding="gbk",dtype={'datetimes':np.datetime64},
               names=['datetimes','open','high','low','close','volume ','amount'],
               )
df
# Out:
# <ipython-input-2-af0bcfcbe8c4>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv(os.getcwd()+"/datas/tdx/SH#600519.csv",
#       datetimes     open     high      low    close   volume         amount
# 0    2015-09-02   115.30   120.19   114.39   119.80  10694546  2.052413e+09
# 1    2015-09-07   117.79   119.19   113.84   113.90   3221642  6.158198e+08
# 2    2015-09-08   113.65   115.66   110.19   114.51   3309858  6.219144e+08
# 3    2015-09-09   115.33   119.06   115.33   117.05   3521516  6.763375e+08
# 4    2015-09-10   115.57   118.49   114.33   118.40   2685248  5.147664e+08
# ...         ...      ...      ...      ...      ...       ...           ...
# 1438 2021-08-02  1664.00  1755.98  1620.72  1755.00   9740065  1.651526e+10
# 1439 2021-08-03  1730.00  1768.99  1688.80  1749.30   5437475  9.447823e+09
# ...

# %%
filename = os.listdir(os.getcwd()+"/datas/tdx")
filename
# Out:
# ['SH#600000.csv',
#  'SH#600004.csv',
#  'SH#600006.csv',
#  'SH#600007.csv',
#  'SH#600008.csv',
#  'SH#600009.csv',
#  'SH#600010.csv',
#  'SH#600011.csv',
#  'SH#600012.csv',
#  'SH#600015.csv',
#  'SH#600016.csv',
#  'SH#600017.csv',
#  'SH#600018.csv',
#  'SH#600019.csv',
#  'SH#600020.csv',
#  'SH#600021.csv',
#  'SH#600022.csv',
#  'SH#600023.csv',
#  'SH#600025.csv',
#  'SH#600026.csv',
#  'SH#600027.csv',
#  'SH#600028.csv',
#  'SH#600029.csv',
#  'SH#600030.csv',
#  'SH#600031.csv',
#  'SH#600032.csv',
#  'SH#600033.csv',
#  'SH#600035.csv',
#  'SH#600036.csv',
#  'SH#600037.csv',
#  'SH#600038.csv',
#  'SH#600039.csv',
#  'SH#600048.csv',
#  'SH#600050.csv',
#  'SH#600051.csv',
#  'SH#600052.csv',
#  'SH#600053.csv',
#  'SH#600054.csv',
#  'SH#600055.csv',
#  'SH#600056.csv',
#  'SH#600057.csv',
#  'SH#600058.csv',
#  'SH#600059.csv',
#  'SH#600060.csv',
#  'SH#600061.csv',
#  'SH#600062.csv',
#  'SH#600063.csv',
#  'SH#600064.csv',
#  'SH#600066.csv',
#  'SH#600067.csv',
# ...
